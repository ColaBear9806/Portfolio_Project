# %%
import os
import cv2

# %%
#!git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '22.jpg',
#  'cfg',
#  'data',
#  'deploy',
#  'detect.py',
#  'export.py',
#  'Fall_Down.ipynb',
#  'figure',
#  'hubconf.py',
#  'inference',
#  'labels',
#  'LICENSE.md',
#  'models',
#  'paper',
#  'README.md',
#  'requirements.txt',
#  'runs',
#  'scripts',
#  'test.py',
#  'tools',
#  'traced_model.pt',
#  'train.py',
#  'train_aux.py',
#  'utils',
#  'yolov7.pt',
#  '__pycache__']

# %%
cd C:/Users/gijon/Desktop/fall2/yolov7/labels
# Out:
# C:\Users\gijon\Desktop\fall2\yolov7\labels

# %%
os.listdir()
# Out:
# ['1.txt',
#  '10.txt',
#  '100.txt',
#  '1000.txt',
#  '1001.txt',
#  '1002.txt',
#  '1003.txt',
#  '1004.txt',
#  '1005.txt',
#  '1006.txt',
#  '1007.txt',
#  '1008.txt',
#  '1009.txt',
#  '101.txt',
#  '1010.txt',
#  '1011.txt',
#  '1012.txt',
#  '1013.txt',
#  '1014.txt',
#  '1015.txt',
#  '1016.txt',
#  '1017.txt',
#  '1019.txt',
#  '102.txt',
#  '1020.txt',
#  '1021.txt',
#  '1022.txt',
#  '1025.txt',
#  '1026.txt',
#  '1029.txt',
#  '103.txt',
#  '1030.txt',
#  '1031.txt',
#  '1032.txt',
#  '1033.txt',
#  '1034.txt',
#  '1035.txt',
#  '1038.txt',
#  '1039.txt',
#  '104.txt',
#  '1040.txt',
#  '1042.txt',
#  '1044.txt',
#  '1045.txt',
#  '1046.txt',
#  '1047.txt',
#  '1048.txt',
#  '105.txt',
#  '1050.txt',
#  '1051.txt',
#  '1052.txt',
#  '1053.txt',
#  '1054.txt',
#  '1056.txt',
#  '1057.txt',
#  '1058.txt',
#  '1059.txt',
#  '106.txt',
#  '1060.txt',
#  '1062.txt',
#  '1063.txt',
#  '1065.txt',
#  '1066.txt',
#  '1067.txt',
#  '1068.txt',
#  '1069.txt',
#  '107.txt',
# ...

# %%
len(os.listdir("C:/Users/gijon/Desktop/fall2/yolov7/labels"))
# Out:
# 673

# %%
file = open("C:/Users/gijon/Desktop/fall2/yolov7/labels/874.txt" , "r")
lines = file.readlines()

for line in lines:
    if line[0] == '0':
        continue

    elif line[0] == '1' :
        continue

    else:
        print(i, line[0])
        file.close()
# Out:
# 1097 3

# %%
import os
import sys

files = os.listdir("C:/Users/gijon/Desktop/fall2/yolov7/labels")
c=0

for i in range(1098):

    try:
        file = open("C:/Users/gijon/Desktop/fall2/yolov7/labels/"+str(i)+".txt" , "r")
        lines = file.readlines()
        for line in lines:
            if line[0] == '0':
                continue

            elif line[0] == '1' :
                continue

            else:
                print(i, line[0])
        file.close()
    except:
        c = c+1
# Out:
# 30 3

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

print(sys.version)
# Out:
# 3.8.13 (default, Mar 28 2022, 06:59:08) [MSC v.1916 64 bit (AMD64)]

# %%
cd C:/Users/gijon/Desktop/fall2/yolov7
# Out:
# C:\Users\gijon\Desktop\fall2\yolov7

# %%
# !python train.py --workers 8 --device 0 --batch-size 8 --epochs 1000 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7_custom.yaml --name yolov7_custom --weights yolov7.pt
# Out:
# ^C

# %% [markdown]
# Test

# %%
# !python test.py --data data/custom_data.yaml --source 22.jpg  --img 640 --batch 32 --conf 0.001 --iou 0.65 --device 0 --weights yolov7.pt --name yolov7_640_val
# Out:
# usage: test.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--data DATA]
#                [--batch-size BATCH_SIZE] [--img-size IMG_SIZE]
#                [--conf-thres CONF_THRES] [--iou-thres IOU_THRES] [--task TASK]
#                [--device DEVICE] [--single-cls] [--augment] [--verbose]
#                [--save-txt] [--save-hybrid] [--save-conf] [--save-json]
#                [--project PROJECT] [--name NAME] [--exist-ok] [--no-trace]
# test.py: error: unrecognized arguments: --source 22.jpg

# %% [markdown]
# Test2

# %%
cd C:/Users/gijon/Desktop/fall2/yolov7
# Out:
# C:\Users\gijon\Desktop\fall2\yolov7

# %%
# !python detect.py --weights ./runs/train/yolov7_custom6/weights/best.pt --conf 0.5 --img-size 640 --source C:/Users/gijon/Desktop/val/images/1139.jpg --device=0
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='0', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='C:/Users/gijon/Desktop/val/images/1139.jpg', update=False, view_img=False, weights=['./runs/train/yolov7_custom6/weights/best.pt'])
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# o
# o
# o
# x
# x
# x
# YOLOR  v0.1-103-g6ded32c torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8191.6875MB)
#
# ...

# %%
# !python detect.py --weights ./runs/train/yolov7_custom6/weights/best.pt --conf 0.5 --img-size 640 --source 0 --device=0
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='0', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='0', update=False, view_img=False, weights=['./runs/train/yolov7_custom6/weights/best.pt'])
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# x
# 0: 1 human, Done. (14.0ms) Inference, (5.0ms) NMS
# o
# 0: 1 falldown, Done. (25.0ms) Inference, (2.0ms) NMS
# o
# 0: 1 falldown, Done. (20.0ms) Inference, (1.0ms) NMS
# 0: Done. (17.0ms) Inference, (0.0ms) NMS
# 0: Done. (18.0ms) Inference, (1.0ms) NMS
# 0: Done. (18.0ms) Inference, (0.0ms) NMS
# 0: Done. (18.0ms) Inference, (1.0ms) NMS
# 0: Done. (16.0ms) Inference, (1.0ms) NMS
# ...
